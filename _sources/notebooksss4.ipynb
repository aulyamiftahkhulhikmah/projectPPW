# %% [markdown]
# # **Cawling Berita Radar Jatim**

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd

# %%
def scraping_berita(halaman):
    a = 1
    data_list = []

    for page in range(1, halaman + 1):
        url = f'https://radarjatim.id/category/hukum-dan-kriminal/page/{page}/'
        html = req.get(url).text
        soup = bs(html, 'lxml')
        list_berita = soup.find('div', class_='jnews_category_content_wrapper').find('div', class_='jeg_block_container').find('div', class_='jeg_posts jeg_load_more_flag')
        berita_list = list_berita.find_all('article')

        for berita in berita_list:
            link = berita.find('div', class_='jeg_postblock_content').find('div', class_='jeg_post_excerpt').find('a')['href']
            headline = berita.find('div', class_='jeg_postblock_content').find('h3', class_='jeg_post_title').find('a').text
            category = berita.find('div', class_='jeg_thumb').find('div', class_='jeg_post_category').find('span').find('a').text

            ge_berita = req.get(link).text
            sop_berita = bs(ge_berita, 'lxml')

            content_elem = sop_berita.find('div', class_='content-inner')
            if content_elem:
                content_list = [p.text.strip() for p in content_elem.find_all('p') if p.text.strip()]
                artikel = ' '.join(content_list).replace('ADVERTISEMENT', '').replace('SCROLL TO RESUME CONTENT', '').strip()
            else:
                artikel = ''

            data_list.append({'Judul': headline, 'Content': artikel, 'Category': category})
            print(f'data berhasil diambil[{a}] > {headline[0:10]}')
            a += 1

    # Membuat DataFrame dari list data
    df = pd.DataFrame(data_list, columns=['Judul', 'Content', 'Category'])
    df

    # Menyimpan DataFrame ke dalam file CSV
    df.to_csv('RadarJatim.csv', index=False, encoding='utf-8')

# pemanggilan fungsi dengan jumlah halaman yang di scraping
scraping_berita(50)
# Out:
# data berhasil diambil[1] > Kemenkumha
# data berhasil diambil[2] > Buntut Ker
# data berhasil diambil[3] > Laporan Du
# data berhasil diambil[4] > Lakukan Pe
# data berhasil diambil[5] > Erick Thoh
# data berhasil diambil[6] > Bupati ber
# data berhasil diambil[7] > Merasa Dir
# data berhasil diambil[8] > Terkait Gu
# data berhasil diambil[9] > Pamekasan
# data berhasil diambil[10] > Hearing Ko
# data berhasil diambil[11] > PTUN Surab
# data berhasil diambil[12] > Bermodalka
# data berhasil diambil[13] > Nina Farid
# data berhasil diambil[14] > Aliansi Pe
# data berhasil diambil[15] > FRB Lapork
# data berhasil diambil[16] > Rekonstruk
# data berhasil diambil[17] > Yunus Susa
# data berhasil diambil[18] > Paguyuban
# data berhasil diambil[19] > Kriminolog
# data berhasil diambil[20] > Sengketa P
# data berhasil diambil[21] > Carut-maru
# data berhasil diambil[22] > Gugatan Di
# data berhasil diambil[23] > Ketua HIPM
# data berhasil diambil[24] > Muscab DPC
# data berhasil diambil[25] > Gagal Medi
# data berhasil diambil[26] > Meriahkan
# data berhasil diambil[27] > Abaikan Re
# data berhasil diambil[28] > Honor Nars
# data berhasil diambil[29] > Kawanan Ma
# data berhasil diambil[30] > DPC Peradi
# data berhasil diambil[31] > Sudah Masu
# data berhasil diambil[32] > PT ISS Ter
# data berhasil diambil[33] > Wawali Arm
# data berhasil diambil[34] > Ratusan An
# data berhasil diambil[35] > Wawali Kaw
# data berhasil diambil[36] > Tjandra Sr
# data berhasil diambil[37] > TRC PPA Ak
# data berhasil diambil[38] > Dugaan Mar
# data berhasil diambil[39] > Dugaan Kor
# data berhasil diambil[40] > Petugas KS
# data berhasil diambil[41] > Densus 88
# data berhasil diambil[42] > Dugaan Mar
# data berhasil diambil[43] > Suap Ketua
# data berhasil diambil[44] > Kades Dian
# data berhasil diambil[45] > Diduga Mar
# data berhasil diambil[46] > Buruh SMC
# data berhasil diambil[47] > Tukar Manf
# data berhasil diambil[48] > Pengancam
# data berhasil diambil[49] > TRC PPA Be
# data berhasil diambil[50] > Yunus Susa
# data berhasil diambil[51] > LPKAN Jati
# data berhasil diambil[52] > Jatim Tert
# data berhasil diambil[53] > MenkumHAM:
# data berhasil diambil[54] > Diduga Jua
# data berhasil diambil[55] > Belum Temu
# data berhasil diambil[56] > Diduga Bap
# data berhasil diambil[57] > Polhutmob
# data berhasil diambil[58] > MA Tolak K
# data berhasil diambil[59] > Modus Duga
# data berhasil diambil[60] > Belum Ada
# data berhasil diambil[61] > Muncul Dug
# data berhasil diambil[62] > Diduga Men
# data berhasil diambil[63] > Bupati LIR
# data berhasil diambil[64] > Saiful Ila
# data berhasil diambil[65] > Diputus Se
# data berhasil diambil[66] > Tertimpa P
# data berhasil diambil[67] > Akhir Sida
# data berhasil diambil[68] > Lapas Nark
# data berhasil diambil[69] > Jaksa Tunt
# data berhasil diambil[70] > Peringati
# data berhasil diambil[71] > Saksi dan
# data berhasil diambil[72] > Bekali Ket
# data berhasil diambil[73] > Perjualbel
# data berhasil diambil[74] > Angkut Rok
# data berhasil diambil[75] > YKBH Banyu
# data berhasil diambil[76] > Terbongkar
# data berhasil diambil[77] > Laporan Du
# data berhasil diambil[78] > Polisi Ama
# data berhasil diambil[79] > Kasek Peng
# data berhasil diambil[80] > Kapolresta
# data berhasil diambil[81] > Kasasi ‘Ba
# data berhasil diambil[82] > Lantik Pen
# data berhasil diambil[83] > Polresta R
# data berhasil diambil[84] > Polsek Bun
# data berhasil diambil[85] > Abaikan So
# data berhasil diambil[86] > Kapolresta
# data berhasil diambil[87] > Empat Terd
# data berhasil diambil[88] > KPK Temuka
# data berhasil diambil[89] > P21, Berka
# data berhasil diambil[90] > Buntut OTT
# data berhasil diambil[91] > PN Surabay
# data berhasil diambil[92] > Lagi, Kali
# data berhasil diambil[93] > KPK Sebut
# data berhasil diambil[94] > Wakil Ketu
# data berhasil diambil[95] > Buntut Tew
# data berhasil diambil[96] > Kasus Pern
# data berhasil diambil[97] > Sah, RUU K
# data berhasil diambil[98] > Menunggu E
# data berhasil diambil[99] > Terima Pen
# data berhasil diambil[100] > Hunian Rut
# data berhasil diambil[101] > KPK Lelang
# data berhasil diambil[102] > Lapas Madi
# data berhasil diambil[103] > Jaringan N
# data berhasil diambil[104] > Terima Pel
# data berhasil diambil[105] > Tren Pered
# data berhasil diambil[106] > Diabaikan
# data berhasil diambil[107] > Tuntut Kea
# data berhasil diambil[108] > Awas, Peni
# data berhasil diambil[109] > Clear dan
# data berhasil diambil[110] > KIPP Lapor
# data berhasil diambil[111] > Tak Setor
# data berhasil diambil[112] > Terseret N
# data berhasil diambil[113] > Mahasiswi
# data berhasil diambil[114] > Tragedi St
# data berhasil diambil[115] > Gelar Aksi
# data berhasil diambil[116] > Penangguha
# data berhasil diambil[117] > Empat Peng
# data berhasil diambil[118] > Puluhan Pe
# data berhasil diambil[119] > Faqih Usma
# data berhasil diambil[120] > OTT di Lap
# data berhasil diambil[121] > Kapolsek S
# data berhasil diambil[122] > Maraknya K
# data berhasil diambil[123] > Kejari Gre
# data berhasil diambil[124] > Diduga Gun
# data berhasil diambil[125] > WNA Vietna
# data berhasil diambil[126] > Tekan Angk
# data berhasil diambil[127] > Sembilan N
# data berhasil diambil[128] > Setelah Ga
# data berhasil diambil[129] > Galang Tan
# data berhasil diambil[130] > Erick Thoh
# data berhasil diambil[131] > DPRD Pamek
# data berhasil diambil[132] > Polres Gre
# data berhasil diambil[133] > 48 Andikpa
# data berhasil diambil[134] > Kecam Pern
# data berhasil diambil[135] > BPN Jatim
# data berhasil diambil[136] > Seluruh WN
# data berhasil diambil[137] > Susul 3 Te
# data berhasil diambil[138] > Akhirnya,
# data berhasil diambil[139] > Tiga Tersa
# data berhasil diambil[140] > Diduga Kor
# data berhasil diambil[141] > Polresta S
# data berhasil diambil[142] > Rutan Sura
# data berhasil diambil[143] > Sidak Lapa
# data berhasil diambil[144] > Polres Gre
# data berhasil diambil[145] > Satpol PP
# data berhasil diambil[146] > Kanwil Kem
# data berhasil diambil[147] > Tersangka
# data berhasil diambil[148] > Dugaan Sal
# data berhasil diambil[149] > Delapan Na
# data berhasil diambil[150] > HMI Gresik
# data berhasil diambil[151] > Heboh Vide
# data berhasil diambil[152] > Satpol PP
# data berhasil diambil[153] > Holywings
# data berhasil diambil[154] > Kejari Gre
# data berhasil diambil[155] > Heboh Kasu
# data berhasil diambil[156] > Belum Teta
# data berhasil diambil[157] > Petugas La
# data berhasil diambil[158] > Petugas La
# data berhasil diambil[159] > Kembangkan
# data berhasil diambil[160] > Panggil Pe
# data berhasil diambil[161] > 20 Desa/Ke
# data berhasil diambil[162] > Gerak Cepa
# data berhasil diambil[163] > Diduga Sel
# data berhasil diambil[164] > Kebutuhan
# data berhasil diambil[165] > Broker Kay
# data berhasil diambil[166] > Polres Gre
# data berhasil diambil[167] > Kejari Gre
# data berhasil diambil[168] > Cegah Nark
# data berhasil diambil[169] > Sinergi P4
# data berhasil diambil[170] > Polisi Rin
# data berhasil diambil[171] > 10 Tahun D
# data berhasil diambil[172] > Menkumham
# data berhasil diambil[173] > Dugaan Maf
# data berhasil diambil[174] > Oknum Poli
# data berhasil diambil[175] > 21 WBP Bud
# data berhasil diambil[176] > Dua Napite
# data berhasil diambil[177] > Para Saksi
# data berhasil diambil[178] > Sinergi de
# data berhasil diambil[179] > Pernah Jad
# data berhasil diambil[180] > Asyik Dudu
# data berhasil diambil[181] > Tim Tabur
# data berhasil diambil[182] > Dokter Gad
# data berhasil diambil[183] > Diduga Men
# data berhasil diambil[184] > Pasca Keba
# data berhasil diambil[185] > Polsek Run
# data berhasil diambil[186] > Edarkan Ua
# data berhasil diambil[187] > Viral Pria
# data berhasil diambil[188] > LIRA : Kej
# data berhasil diambil[189] > Polsek Run
# data berhasil diambil[190] > Berbekal G
# data berhasil diambil[191] > Kapolresta
# data berhasil diambil[192] > Anak Ditem
# data berhasil diambil[193] > Demi Terci
# data berhasil diambil[194] > Peringati
# data berhasil diambil[195] > Imigrasi S
# data berhasil diambil[196] > 14.395 WBP
# data berhasil diambil[197] > PN Mojoker
# data berhasil diambil[198] > Jelang Leb
# data berhasil diambil[199] > Bupati Tin
# data berhasil diambil[200] > MS Menangi
# data berhasil diambil[201] > Aksi Demo
# data berhasil diambil[202] > Lapas Kela
# data berhasil diambil[203] > Balap Liar
# data berhasil diambil[204] > Jelang Ram
# data berhasil diambil[205] > Jelang Ram
# data berhasil diambil[206] > Sat Pol PP
# data berhasil diambil[207] > 67 Notaris
# data berhasil diambil[208] > Kapolda Re
# data berhasil diambil[209] > Pemkab Sid
# data berhasil diambil[210] > Dirjen Bad
# data berhasil diambil[211] > Kapolres P
# data berhasil diambil[212] > Polres Pam
# data berhasil diambil[213] > Kapolri Be
# data berhasil diambil[214] > Kapolri Si
# data berhasil diambil[215] > Imigrasi S
# data berhasil diambil[216] > Lapas Pame
# data berhasil diambil[217] > Ditjenpas
# data berhasil diambil[218] > Kapolri Pa
# data berhasil diambil[219] > Ditjen Imi
# data berhasil diambil[220] > Kasat Binm
# data berhasil diambil[221] > Bebas Bers
# data berhasil diambil[222] > Optimalkan
# data berhasil diambil[223] > Kadivpas O
# data berhasil diambil[224] > Papan Nama
# data berhasil diambil[225] > Polresta S
# data berhasil diambil[226] > Manfaatkan
# data berhasil diambil[227] > Stres sete
# data berhasil diambil[228] > Kartar Apr
# data berhasil diambil[229] > Diduga Seb
# data berhasil diambil[230] > Seriusi Pe
# data berhasil diambil[231] > Keren! Sem
# data berhasil diambil[232] > Layanan Ca
# data berhasil diambil[233] > Tragis, Pe
# data berhasil diambil[234] > Di Jatim,
# data berhasil diambil[235] > Kades Bang
# data berhasil diambil[236] > Hari Raya
# data berhasil diambil[237] > BHS: Kapol
# data berhasil diambil[238] > Kanimsus J
# data berhasil diambil[239] > Sempat Bur
# data berhasil diambil[240] > Lapas Sido
# data berhasil diambil[241] > Dugaan Hoa
# data berhasil diambil[242] > Perkuat Si
# data berhasil diambil[243] > Debitur Wa
# data berhasil diambil[244] > Kemenkumha
# data berhasil diambil[245] > Deteni Rud
# data berhasil diambil[246] > Dikawal 50
# data berhasil diambil[247] > Polres Gre
# data berhasil diambil[248] > Terkait Ho
# data berhasil diambil[249] > Tiga Warga
# data berhasil diambil[250] > FKUB Kutuk
# data berhasil diambil[251] > Pastikan M
# data berhasil diambil[252] > Buka Salon
# data berhasil diambil[253] > Agar Situa
# data berhasil diambil[254] > Jadi Korba
# data berhasil diambil[255] > SMA Antart
# data berhasil diambil[256] > Gandeng BL
# data berhasil diambil[257] > Blok Hunia
# data berhasil diambil[258] > Diputus MA
# data berhasil diambil[259] > Gandeng Ke
# data berhasil diambil[260] > Terkait Pe
# data berhasil diambil[261] > BNNK Gresi
# data berhasil diambil[262] > Alihkan As
# data berhasil diambil[263] > Lapas Pame
# data berhasil diambil[264] > Plt Kadivp
# data berhasil diambil[265] > Lapas Sura
# data berhasil diambil[266] > BNNK Ajak
# data berhasil diambil[267] > Minimalkan
# data berhasil diambil[268] > Kantor Imi
# data berhasil diambil[269] > 25 Narapid
# data berhasil diambil[270] > Membangkan
# data berhasil diambil[271] > Petugas Ru
# data berhasil diambil[272] > Pelaku Ter
# data berhasil diambil[273] > Lapas Peka
# data berhasil diambil[274] > Back to Ba
# data berhasil diambil[275] > Eks Pimpin
# data berhasil diambil[276] > Lapas Banc
# data berhasil diambil[277] > UPT Kumham
# data berhasil diambil[278] > Peradi SAI
# data berhasil diambil[279] > Terdampak
# data berhasil diambil[280] > Sambingi A
# data berhasil diambil[281] > Mantan Bup
# data berhasil diambil[282] > Petugas La
# data berhasil diambil[283] > Kapolresta
# data berhasil diambil[284] > Antisipasi
# data berhasil diambil[285] > Petugas La
# data berhasil diambil[286] > Selama 202
# data berhasil diambil[287] > Susul Ters
# data berhasil diambil[288] > Ka Polsek
# data berhasil diambil[289] > Forkopimda
# data berhasil diambil[290] > Gelar Rako
# data berhasil diambil[291] > Malam Tahu
# data berhasil diambil[292] > Mengaku Po
# data berhasil diambil[293] > Kapolresta
# data berhasil diambil[294] > Kapolres M
# data berhasil diambil[295] > Rutan Sura
# data berhasil diambil[296] > Kapolresta
# data berhasil diambil[297] > Pemkab Sid
# data berhasil diambil[298] > Buronan Ke
# data berhasil diambil[299] > Kasatreskr
# data berhasil diambil[300] > Rutan Gres
# data berhasil diambil[301] > Berhasil T
# data berhasil diambil[302] > 53 UPT Jaj
# data berhasil diambil[303] > Polresta S
# data berhasil diambil[304] > Gandeng Wa
# data berhasil diambil[305] > Kapolresta
# data berhasil diambil[306] > Polisi Tan
# data berhasil diambil[307] > Kanwil Kem
# data berhasil diambil[308] > Polresta S
# data berhasil diambil[309] > Polresta S
# data berhasil diambil[310] > Rutan Gres
# data berhasil diambil[311] > Di Rutan G
# data berhasil diambil[312] > Lapas Bany
# data berhasil diambil[313] > Warga Bina
# data berhasil diambil[314] > Kunker di
# data berhasil diambil[315] > Komisi III
# data berhasil diambil[316] > Terbongkar
# data berhasil diambil[317] > Dua Lapas
# data berhasil diambil[318] > Timpora Mo
# data berhasil diambil[319] > Kuasa Huku
# data berhasil diambil[320] > Kemenkumha
# data berhasil diambil[321] > Hiperhu Du
# data berhasil diambil[322] > Ditresnark
# data berhasil diambil[323] > Pertajam K
# data berhasil diambil[324] > Lapas Sura
# data berhasil diambil[325] > DPP Golkar
# data berhasil diambil[326] > Nenek Pemb
# data berhasil diambil[327] > Kantah Sur
# data berhasil diambil[328] > Kemenkumha
# data berhasil diambil[329] > Kemenkumha
# data berhasil diambil[330] > George: Ji
# data berhasil diambil[331] > Polisi Vak
# data berhasil diambil[332] > Kemampuan
# data berhasil diambil[333] > Ibu Kandun
# data berhasil diambil[334] > Tim Patrol
# data berhasil diambil[335] > Geledah Bl
# data berhasil diambil[336] > 23 Senpi P
# data berhasil diambil[337] > Kemenkumha
# data berhasil diambil[338] > Rutan Gres
# data berhasil diambil[339] > Sipenjawab
# data berhasil diambil[340] > 450 Pemuda
# data berhasil diambil[341] > Jual Tabun
# data berhasil diambil[342] > Divonis 6
# data berhasil diambil[343] > Dapat Remi
# data berhasil diambil[344] > Tak Lolos
# data berhasil diambil[345] > Soal Empat
# data berhasil diambil[346] > PPKM Darur
# data berhasil diambil[347] > Salurkan B
# data berhasil diambil[348] > Dandim dan
# data berhasil diambil[349] > Kades Temu
# data berhasil diambil[350] > Perhutani
# data berhasil diambil[351] > Babak Baru
# data berhasil diambil[352] > Panglima T
# data berhasil diambil[353] > JCW Cium A
# data berhasil diambil[354] > Tinjau Vak
# data berhasil diambil[355] > Sidang Dit
# data berhasil diambil[356] > Kalapas Ba
# data berhasil diambil[357] > 2 Juli Mal
# data berhasil diambil[358] > Libatkan E
# data berhasil diambil[359] > Panglima T
# data berhasil diambil[360] > 20 Tim Vak
# data berhasil diambil[361] > Dandim Sur
# data berhasil diambil[362] > 113 Calon
# data berhasil diambil[363] > LSM Yasra
# data berhasil diambil[364] > Aktivis Ba
# data berhasil diambil[365] > Berkerumun
# data berhasil diambil[366] > Subdit III
# data berhasil diambil[367] > Ketua Satg
# data berhasil diambil[368] > Jualan Dit
# data berhasil diambil[369] > Kunjungi K
# data berhasil diambil[370] > Bubarkan T
# data berhasil diambil[371] > 12 Warga L
# data berhasil diambil[372] > Antisipasi
# data berhasil diambil[373] > Lagi, Dens
# data berhasil diambil[374] > Kapolda Ja
# data berhasil diambil[375] > Puluhan Wa
# data berhasil diambil[376] > Pengakuan
# data berhasil diambil[377] > Penganiaya
# data berhasil diambil[378] > Pasca Tero
# data berhasil diambil[379] > Gelar FGD,
# data berhasil diambil[380] > Peringati
# data berhasil diambil[381] > Personel P
# data berhasil diambil[382] > 22 Terduga
# data berhasil diambil[383] > Apel Besar
# data berhasil diambil[384] > Rugi Puluh
# data berhasil diambil[385] > Aksi Heroi
# data berhasil diambil[386] > Soal Dugaa
# data berhasil diambil[387] > Bunuh Anak
# data berhasil diambil[388] > Pelajar di
# data berhasil diambil[389] > Kapolresta
# data berhasil diambil[390] > Satreskrim
# data berhasil diambil[391] > Berkunjung
# data berhasil diambil[392] > Polresta S
# data berhasil diambil[393] > Dikepung W
# data berhasil diambil[394] > Lagi, Poli
# data berhasil diambil[395] > Hobi Pamer
# data berhasil diambil[396] > Ditresnark
# data berhasil diambil[397] > Ditreskrim
# data berhasil diambil[398] > Camat Dudu
# data berhasil diambil[399] > Polres Tre
# data berhasil diambil[400] > Resmikan M
# data berhasil diambil[401] > Jatanras P
# data berhasil diambil[402] > PPKM di Ja
# data berhasil diambil[403] > Satnarkoba
# data berhasil diambil[404] > Kumham Jat
# data berhasil diambil[405] > Tim Satres
# data berhasil diambil[406] > Dandim Lam
# data berhasil diambil[407] > Humas Polr
# data berhasil diambil[408] > Polisi Tem
# data berhasil diambil[409] > Tak Kapok,
# data berhasil diambil[410] > Ribuan Vak
# data berhasil diambil[411] > Kasi Intel
# data berhasil diambil[412] > Polisi Tan
# data berhasil diambil[413] > Tak Mau Ba
# data berhasil diambil[414] > Kasus Pung
# data berhasil diambil[415] > Pemuda Pan
# data berhasil diambil[416] > Perundunga
# data berhasil diambil[417] > Keroyok Te
# data berhasil diambil[418] > Serah Teri
# data berhasil diambil[419] > Kasubbag H
# data berhasil diambil[420] > Tak Mau Ke
# data berhasil diambil[421] > Konvoi di
# data berhasil diambil[422] > Pengamanan
# data berhasil diambil[423] > Komisi B S
# data berhasil diambil[424] > Jelang Nat
# data berhasil diambil[425] > Jelang Mis
# data berhasil diambil[426] > Timses Yus
# data berhasil diambil[427] > Mau Kabur,
# data berhasil diambil[428] > Ribuan Mas
# data berhasil diambil[429] > Lagi, Pemu
# data berhasil diambil[430] > Bangorejo
# data berhasil diambil[431] > Usut Tunta
# data berhasil diambil[432] > SCWI: Koru
# data berhasil diambil[433] > Polisi Tet
# data berhasil diambil[434] > Pasukan TN
# data berhasil diambil[435] > Rayakan Pa
# data berhasil diambil[436] > Politikus
# data berhasil diambil[437] > Resmi Pind
# data berhasil diambil[438] > Latihan Me
# data berhasil diambil[439] > KPK Saksik
# data berhasil diambil[440] > Dewan Kebe
# data berhasil diambil[441] > Pemkot Sur
# data berhasil diambil[442] > Siap-Siap
# data berhasil diambil[443] > Pemkot Sur
# data berhasil diambil[444] > Kemendagri
# data berhasil diambil[445] > Advokat in
# data berhasil diambil[446] > Setubuhi A
# data berhasil diambil[447] > Bikin Bisi
# data berhasil diambil[448] > Urung Tila
# data berhasil diambil[449] > Sidang Kod
# data berhasil diambil[450] > Duga Ada F
# data berhasil diambil[451] > Langgar At
# data berhasil diambil[452] > MA Vonis M
# data berhasil diambil[453] > Demo Tolak
# data berhasil diambil[454] > Bocah SMP
# data berhasil diambil[455] > Bocah SMP
# data berhasil diambil[456] > BNN Jatim
# data berhasil diambil[457] > Selundupka
# data berhasil diambil[458] > Cemburu Bu
# data berhasil diambil[459] > Polres Gre
# data berhasil diambil[460] > Kontras Te
# data berhasil diambil[461] > Sempat Due
# data berhasil diambil[462] > Tolak Perw
# data berhasil diambil[463] > Operasi Yu
# data berhasil diambil[464] > Siswa SMP
# data berhasil diambil[465] > Polisi Mas
# data berhasil diambil[466] > Gugatan Pr
# data berhasil diambil[467] > Yustisi Ma
# data berhasil diambil[468] > 22 Perusuh
# data berhasil diambil[469] > Polisi Bur
# data berhasil diambil[470] > Kasus Pemi
# data berhasil diambil[471] > Pejuang Su
# data berhasil diambil[472] > Saiful Ila
# data berhasil diambil[473] > Pelaku Cur
# data berhasil diambil[474] > Diduga Jad
# data berhasil diambil[475] > Terekam CC
# data berhasil diambil[476] > Perkembang
# data berhasil diambil[477] > Aksi Vadal
# data berhasil diambil[478] > Polisi Sur
# data berhasil diambil[479] > Bacok Poli
# data berhasil diambil[480] > Jual Cewek
# data berhasil diambil[481] > Tak Pakai
# data berhasil diambil[482] > Berkas Kas
# data berhasil diambil[483] > Razia Prok
# data berhasil diambil[484] > Jenguk Sye
# data berhasil diambil[485] > Usai Dor G
# data berhasil diambil[486] > Saiful Ila
# data berhasil diambil[487] > Penusukan
# data berhasil diambil[488] > Awas, Tida
# data berhasil diambil[489] > Operasi Yu
# data berhasil diambil[490] > Orang Gila
# data berhasil diambil[491] > Polisi Dal
# data berhasil diambil[492] > Ustadz Sye
# data berhasil diambil[493] > Berkerumun
# data berhasil diambil[494] > Gembong Na
# data berhasil diambil[495] > Miras Bera
# data berhasil diambil[496] > Ops Mantap
# data berhasil diambil[497] > Pasutri Ko
# data berhasil diambil[498] > Kejari Gel
# data berhasil diambil[499] > Tak Patuh
# data berhasil diambil[500] > Pencegahan
